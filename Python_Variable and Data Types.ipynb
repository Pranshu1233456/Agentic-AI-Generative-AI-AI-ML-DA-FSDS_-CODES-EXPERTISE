# %%
import  sys
sys. version
# Out:
# '3.13.5 | packaged by Anaconda, Inc. | (main, Jun 12 2025, 16:37:03) [MSC v.1929 64 bit (AMD64)]'

# %% [markdown]
# pyhon variable =identifier=object
#
# syntax(variable=value)

# %%
v=5
v
# Out:
# 5

# %% [raw]
# Rules to Declare Python Variable

# %%
var=8             # variable case sensitive
VAR
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 var=8             # variable case sensitive
# ----> 2 VAR
#
# NameError: name 'VAR' is not defined

# %%
var
# Out:
# 8

# %%
v@=5              #special symbol not allowe in the variable
v@
# Out:
#   Cell In[6], line 2
#     v@
#       ^
# SyntaxError: invalid syntax

# %%
v_=8              # only _ is allowed
v_
# Out:
# 8

# %%
_v=9
_v
# Out:
# 9

# %%
1var=10    #variable does not start with digit
1var
# Out:
#   Cell In[9], line 1
#     1var=10    #variable does not start with digit
#     ^
# SyntaxError: invalid decimal literal

# %%
var1=11           #varible can end with digit
var1
# Out:
# 11

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
len(keyword.kwlist)
# Out:
# 35

# %%
# Python Variable Declartion

# %%
age=25            # Integer Variable
print(age)
# Out:
# 25

# %%
name='Pranshu'   # String Variable
print(name)
# Out:
# Pranshu

# %%
price=19.99      # Float Variable
print(price)
# Out:
# 19.99

# %%
is_active=True  # Boolean Variable
print(is_active)
# Out:
# True

# %%
x=10
print(x)
# Out:
# 10

# %%
a=5
b=6
result=a+b
print(result)
# Out:
# 11

# %%
score=50
print(score)
# Out:
# 50

# %%
first_name="John"
last_name="Doe"

full_name=first_name + " " + last_name
print(full_name)
# Out:
# John Doe

# %%
length=10
width=5

area=length*width
print(area)
# Out:
# 50

# %% [markdown]
# #Python Data Types
#
#   int
#   float
#   bool
#   string
#   complex

# %%
i=5
i
# Out:
# 5

# %%
type(i)
# Out:
# int

# %%
f=110.45
f
# Out:
# 110.45

# %%
type(f)
# Out:
# float

# %%
print(i)
print(f)
# Out:
# 5
# 110.45

# %%
i+f
# Out:
# 115.45

# %%
i*f
# Out:
# 552.25

# %%
i-f
# Out:
# -105.45

# %%
i/f
# Out:
# 0.04526935264825713

# %% [markdown]
# Boolean

# %%
true
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 true
#
# NameError: name 'true' is not defined

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
True+False
# Out:
# 1

# %%
False+True
# Out:
# 1

# %%
False+False
# Out:
# 0

# %%
True/True
# Out:
# 1.0

# %%
True//True
# Out:
# 1

# %% [markdown]
# String

# %%
s='hello'
s
# Out:
# 'hello'

# %%
s1="Good Morning"
s1
# Out:
# 'Good Morning'

# %%
s2='''hello
        team'''
s2
# Out:
# 'hello\n        team'

# %% [markdown]
# Complex

# %%
c=10+20j
c
# Out:
# (10+20j)

# %%
c.real
# Out:
# 10.0

# %%
c.imag
# Out:
# 20.0

# %%
c=10+20j
d=20+30j

# %%
print(c+d)
# Out:
# (30+50j)

# %%
print(c-d)
# Out:
# (-10-10j)

# %%
print(c*d)
# Out:
# (-400+700j)

# %%
print(c/d)
# Out:
# (0.6153846153846154+0.0769230769230769j)
